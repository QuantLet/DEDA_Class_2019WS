# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly

# %% [markdown]
# ## 1. Price

# %% [markdown]
# ### 1. - 1) Raw price

# %%
price = pd.read_csv('1718hourlyPrice_withZEC.csv', index_col = 'time')
price.index = pd.to_datetime(price.index)


# fig = go.Figure()
# for coin in price.columns:
#     fig.add_trace(go.Scatter(x=price.index, y=price[coin],name = coin))

# fig.update_layout(title="Hourly Price")
# plotly.offline.plot(fig,filename="Hourly Price.html")

# %% [markdown]
# ### 1. - 2) Log price

# %%
LogPrice = np.log(price)
LogPrice.index = pd.to_datetime(LogPrice.index)


# fig = go.Figure()
# for coin in LogPrice.columns:
#     fig.add_trace(go.Scatter(x=LogPrice.index, y=LogPrice[coin],name = coin))

# fig.update_layout(title="Log Hourly Price")
# plotly.offline.plot(fig,filename="Log Hourly Price.html")

# %% [markdown]
# ### 1. - 3) Standardized price

# %%
StdPrice = (price - price.mean(0)) / price.std(0)
StdPrice.index = pd.to_datetime(StdPrice.index)


# fig = go.Figure()
# for coin in StdPrice.columns:
#     fig.add_trace(go.Scatter(x=StdPrice.index, y=StdPrice[coin],name = coin))

# fig.update_layout(title="Standardized Hourly Price")
# plotly.offline.plot(fig,filename="Standardized Hourly Price.html")

# %% [markdown]
# #### Export the graph as a png file

# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import matplotlib
from matplotlib.dates import MonthLocator, DateFormatter
import matplotlib.dates as mdates


fig =  plt.figure(figsize = (12, 18))
ax1 = fig.add_subplot(311)

for coin in price.columns:
    ax1.plot(price.index, price[coin], label = coin, linewidth=1)

ax1.grid(axis = 'y')



date = price.index.to_pydatetime()

ax1.set_xlim([date[0], date[-1]])

ax1.xaxis.set_major_locator(MonthLocator())
ax1.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax1.title.set_text("Hourly Price")


ax2 = fig.add_subplot(312)

for coin in LogPrice.columns:
    ax2.plot(LogPrice.index, LogPrice[coin], label = coin, linewidth=1)

ax2.grid(axis = 'y')

date = LogPrice.index.to_pydatetime()

ax2.set_xlim([date[0], date[-1]])

ax2.xaxis.set_major_locator(MonthLocator())
ax2.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.spines["left"].set_visible(False)

ax2.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax2.title.set_text("Log Hourly Price")


ax3 = fig.add_subplot(313)

for coin in StdPrice.columns:
    ax3.plot(StdPrice.index, StdPrice[coin], label = coin, linewidth=1)

ax3.grid(axis = 'y')
ax3.legend(prop={'size': 8}, frameon=False)

ax3.title.set_text("Standardized Hourly Price")


date = StdPrice.index.to_pydatetime()

ax3.set_xlim([date[0], date[-1]])

ax3.xaxis.set_major_locator(MonthLocator())
ax3.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax3.spines["top"].set_visible(False)
ax3.spines["right"].set_visible(False)
ax3.spines["bottom"].set_visible(False)
ax3.spines["left"].set_visible(False)


plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()


# fig.savefig('Price data analysis.png')

# %% [markdown]
# ## 2. Return

# %% [markdown]
# ### 2. - 1) Raw return

# %%
returns = pd.read_csv('1718hourlyReturn_withZEC.csv', index_col = 'time')
returns.index = pd.to_datetime(returns.index)


# fig = go.Figure()
# for coin in returns.columns:
#     fig.add_trace(go.Scatter(x=returns.index, y=returns[coin],name = coin))

# fig.update_layout(title="Hourly Return")
# plotly.offline.plot(fig,filename="Hourly Return.html")

# %% [markdown]
# ### 2. - 2) Standardized return

# %%
returnsStd = (returns - returns.mean(0)) / returns.std(0)

# fig = go.Figure()
# for coin in returnsStd.columns:
#     fig.add_trace(go.Scatter(x=returnsStd.index, y=returnsStd[coin],name = coin))

# fig.update_layout(title="Standardized Hourly Return")
# plotly.offline.plot(fig,filename="Standardized Hourly Return.html")

# %% [markdown]
# #### Export the graph as a png file

# %%
fig =  plt.figure(figsize = (12, 12))
ax1 = fig.add_subplot(211)

for coin in returns.columns:
    ax1.plot(returns.index, returns[coin], label = coin, linewidth=1)

ax1.grid(axis = 'y')



date = returns.index.to_pydatetime()

ax1.set_xlim([date[0], date[-1]])

ax1.xaxis.set_major_locator(MonthLocator())
ax1.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax1.title.set_text("Hourly Return")


ax2 = fig.add_subplot(212)

for coin in returnsStd.columns:
    ax2.plot(returnsStd.index, returnsStd[coin], label = coin, linewidth=1)

ax2.grid(axis = 'y')

date = returnsStd.index.to_pydatetime()

ax2.set_xlim([date[0], date[-1]])

ax2.xaxis.set_major_locator(MonthLocator())
ax2.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.spines["left"].set_visible(False)

ax2.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax2.title.set_text("Standardized Hourly Return")



plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()


# fig.savefig('Return data analysis.png')

# %% [markdown]
# ## 3. Macroeconomic index

# %% [markdown]
# ### 3. - 1) Raw macro index

# %%
macro = pd.read_csv('macro1718.csv', index_col = 'Datetime')
macro.index = pd.to_datetime(macro.index)

# fig = go.Figure()
# for i in macro.columns:
#     fig.add_trace(go.Scatter(x=macro.index, y=macro[i],name = i))

# fig.update_layout(title="Macroeconomic variables")
# plotly.offline.plot(fig,filename="Macroeconomic variables.html")

# %% [markdown]
# ### 3. - 2) Standardized macro index

# %%
macroStand = (macro - macro.mean(0))/macro.std(0)

# fig = go.Figure()
# for i in macroStand.columns:
#     fig.add_trace(go.Scatter(x=macroStand.index, y=macroStand[i],name = i))

# fig.update_layout(title="Standardized Macroeconomic variables")
# plotly.offline.plot(fig,filename="Standardized Macroeconomic variables.html")
# Out:
# 'Standardized Macroeconomic variables.html'

# %% [markdown]
# #### Export the graph as a png file

# %%
fig =  plt.figure(figsize = (12, 12))
ax1 = fig.add_subplot(211)

for coin in macro.columns:
    ax1.plot(macro.index, macro[coin], label = coin, linewidth=1)

ax1.grid(axis = 'y')



date = macro.index.to_pydatetime()

ax1.set_xlim([date[0], date[-1]])

ax1.xaxis.set_major_locator(MonthLocator())
ax1.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax1.title.set_text("Macro Economic Variables")


ax2 = fig.add_subplot(212)

for coin in macroStand.columns:
    ax2.plot(macroStand.index, macroStand[coin], label = coin, linewidth=1)

ax2.grid(axis = 'y')

date = macroStand.index.to_pydatetime()

ax2.set_xlim([date[0], date[-1]])

ax2.xaxis.set_major_locator(MonthLocator())
ax2.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.spines["left"].set_visible(False)

ax2.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax2.title.set_text("Standardized Macro Economic Variables")



plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()


# fig.savefig('Macro-economic data analysis.png')

# %% [markdown]
# ## 4. Macroeconomic index Return

# %% [markdown]
# ### 3. - 1) Raw macro index Return

# %%
macroRT = pd.read_csv('macro1718_return.csv', index_col = 'Datetime')
macroRT.index = pd.to_datetime(macroRT.index)

# fig = go.Figure()
# for i in macroRT.columns:
#     fig.add_trace(go.Scatter(x=macroRT.index, y=macroRT[i],name = i))

# fig.update_layout(title="Macroeconomic variables Return")
# plotly.offline.plot(fig,filename="Macroeconomic variables Return.html")

# %% [markdown]
# ### 3. - 2) Standardized macro index Return

# %%
macroRTStand = (macroRT - macroRT.mean(0))/macroRT.std(0)

# fig = go.Figure()
# for i in macroRTStand.columns:
#     fig.add_trace(go.Scatter(x=macroRTStand.index, y=macroRTStand[i],name = i))

# fig.update_layout(title="Standardized Macroeconomic variables Return")
# plotly.offline.plot(fig,filename="Standardized Macroeconomic variables Return.html")
# Out:
# 'Standardized Macroeconomic variables Return.html'

# %% [markdown]
# #### Export the graph as a png file

# %%
fig =  plt.figure(figsize = (12, 12))
ax1 = fig.add_subplot(211)

for coin in macroRT.columns:
    ax1.plot(macroRT.index, macroRT[coin], label = coin, linewidth=1)

ax1.grid(axis = 'y')


date = macroRT.index.to_pydatetime()

ax1.set_xlim([date[0], date[-1]])

ax1.xaxis.set_major_locator(MonthLocator())
ax1.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["left"].set_visible(False)
ax1.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax1.title.set_text("macro Economic Variables Return")


ax2 = fig.add_subplot(212)

for coin in macroRTStand.columns:
    ax2.plot(macroRTStand.index, macroRTStand[coin], label = coin, linewidth=1)

ax2.grid(axis = 'y')

date = macroRTStand.index.to_pydatetime()

ax2.set_xlim([date[0], date[-1]])

ax2.xaxis.set_major_locator(MonthLocator())
ax2.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)
ax2.spines["bottom"].set_visible(False)
ax2.spines["left"].set_visible(False)

ax2.legend(loc= 'upper right', prop={'size': 8}, frameon=False)
ax2.title.set_text("Standardized macro Economic Variables Return")



plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()


fig.savefig('Data_Analysis_MacroReturn.png')
